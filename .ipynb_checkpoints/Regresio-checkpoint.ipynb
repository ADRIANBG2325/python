# %% [markdown]
# Regresion lineal:Costo de un insidente de seguridad

# %% [markdown]
# En este ejercicio se explica

# %% [markdown]
# ## Enunciado

# %% [markdown]
# el ejercicio consiste en el costo de un incidente de seguridad en base al numero de equipos

# %% [markdown]
# ### 1.Generacion de conjunto de datos o data sev

# %%
import numpy as np
X =2*np.random.rand(5000,1)
y=4+3*X+np.random.randn(5000,1)

print("La longitud del conjunto de estos es:",len(X))
# Out:
# La longitud del conjunto de estos es: 5000

# %% [markdown]
# ### 2.Visualizacion del DataSet.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(X,y,"b.")
plt.show()

# %%
plt.plot(X,y,"g.")
plt.xlabel("eq afectados (u/1,000)")
plt.ylabel("costo del incidente(u/10,000)")
plt.title("costo")
# Out:
# Text(0.5, 1.0, 'costo')

# %% [markdown]
# ### data sev

# %%
import pandas as pd

# %%
data = {'No_equipos_afectados':X.flatten(),'costo':y.flatten()}
df=pd.DataFrame(data)
df.head(5000)
# Out:
#       No_equipos_afectados     costo
# 0                 1.638845  8.567631
# 1                 0.665478  4.043083
# 2                 1.181449  6.846760
# 3                 1.542039  9.497323
# 4                 1.602420  9.977944
# ...                    ...       ...
# 4995              0.578832  4.388199
# 4996              1.641400  8.073009
# 4997              1.590725  7.914831
# 4998              0.097309  4.309732
# 4999              0.406041  4.318761
#
# [5000 rows x 2 columns]

# %%
# escalado del numero de equipos afectados
df['No_equipos_afectados']=df['No_equipos_afectados']*1000
df['No_equipos_afectados']=df['No_equipos_afectados'].astype('int')
# escalar costo
df['costo']=df['costo']*10000
df['costo']=df['costo'].astype('int')
df.head(10)
# Out:
#    No_equipos_afectados  costo
# 0                  1638  85676
# 1                   665  40430
# 2                  1181  68467
# 3                  1542  94973
# 4                  1602  99779
# 5                   767  61670
# 6                  1656  92855
# 7                  1837  99835
# 8                   307  40389
# 9                  1693  72792

# %%
#representacion grafica del dataset
plt.plot(df['No_equipos_afectados'],df['costo'],"b.")
plt.xlabel("Equipos afectados")
plt.ylabel("costo del incidente")
plt.show()

# %% [markdown]
# modelo

# %%
from sklearn.linear_model import LinearRegression

# %%
# construccion del modelo y ajuste de la funcion de hipotesis

# %%
lin_reg= LinearRegression()
lin_reg.fit(df["No_equipos_afectados"].values.reshape(-1,1),df["costo"].values)
# Out:
# LinearRegression()

# %%
# parametro Theta 0 
lin_reg.intercept_
# Out:
# 39904.77578792989

# %%
# Parametro Theta 1
lin_reg.coef_
# Out:
# array([29.90871915])

# %%
# Predccion para el valor minimo y maximo del conjunto de datos de entrenamiento
X_min_max=np.array([[df["No_equipos_afectados"].min()],[df["No_equipos_afectados"].max()]])
y_train_pred = lin_reg.predict(X_min_max)

# %%
# Representacion grafica de la representacion de hipotesis generada
plt.plot(X_min_max, y_train_pred,"g-")
plt.plot(df["No_equipos_afectados"],df["costo"],"b.")
plt.xlabel("Equipos_afectados")
plt.xlabel("costo del incidente")
plt.show()

# %% [markdown]
# ## 5. preddiccion nuevos ejemplos

# %%
x_new=np.array([[1500]]) #1300 equipos afectados
# predccion del costo que tendria el incidente
costo = lin_reg.predict(x_new)
print  ("el costo del incidente seria  $:", int(costo[0]))
# Out:
# el costo del incidente seria  $: 84767

# %%
plt.plot(df['No_equipos_afectados'],df['costo'],'b.')
plt.plot(X_min_max, y_train_pred,("g-"))
plt.plot(x_new, costo, "rx")
plt.xlabel('equipos afectados')
plt.ylabel('prediccion')
plt.show()
