# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#Cargar el DataFrame en Jupiter.
df3 = pd.read_csv("dstos.csv", index_col = 0)
df3
# Out:
#            yi
# xi
# 65.78  112.99
# 71.52  136.49
# 69.40  153.03
# 68.22  142.34
# 67.79  144.30
# ...       ...
# 65.80  120.84
# 66.11  115.78
# 68.24  128.30
# 68.02  127.47
# 71.39  127.88
#
# [200 rows x 1 columns]

# %%
plt.title("oda")
plt.plot(df3,'b.')
plt.xlabel("piola")
plt.grid(True)
plt.show()

# %%
import numpy as np
x=2*np.random.rand(5000,1)
y=4+3*x+np.random.randn(5000,1)
print("La longitud del conjunto de estos es:",len(x))
plt.plot(x,y,'b.')
plt.show()
# Out:
# La longitud del conjunto de estos es: 5000
